# %% [markdown]
# # Tutorial7: 使用LLaMA-Factory完成Qwen2.5大模型的微调、推理
#
# 建议在SCOW AI集群运行本教程。
#
# 本节以Qwen2.5-1.5B-Instruct模型为例，给出其使用LLaMA-Factory完成微调、推理的步骤.
#
# 分以下几步来实现：
# 1. 创建vscode应用，使用平台提供的LLaMA-Factory镜像
# 2. 按照镜像中的文档完成大模型的微调和推理
#
# 建议使用1张910B NPU运行本教程。

# %% [markdown]
# ## 1、拉取镜像并安装
#
# 1.1 创建作业
#
# 登录SCOW平台，进入AI集群，然后点击作业->创建作业->vscode
#
# ![image.png](attachment:image.png)
#
# 在创建vscode页面中，选择LLaMA-Factory公共镜像、选择Qwen2.5-1.5B-Instruct作为基础模型，提交
#
# ![image-5.png](attachment:image-5.png)
#
# 待作业状态为Running，点击连接进入vscode应用
# ![image-2.png](attachment:image-2.png)
#
# 开启终端命令
#
# ![image-3.png](attachment:image-3.png)
#
# 按照step0_README.md的提示进行模型微调和推理
# ![image-6.png](attachment:image-6.png)
# ```

# %% [markdown]
# ---
#
# > 作者: 石晶; 黎颖; 褚苙扬; 龙汀汀
# >
# > 联系方式: yingliclaire@pku.edu.cn; cly2412307718@stu.pku.edu.cn; l.tingting@pku.edu.cn
